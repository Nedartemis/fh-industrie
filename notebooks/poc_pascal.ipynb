# %% [markdown]
# # POC Pascal

# %% [markdown]
# ## Imports

# %%
import init_path

# %%
import camelot
import pandas as pd
from PyPDF2 import PdfReader, PdfWriter

import backend.ocr
from vars import PATH_DOCS_PASCALE, PATH_TMP

# %% [markdown]
# ## Cut pdf

# %%
file_name = PATH_DOCS_PASCALE / "1-extrait CR chantier St Amand 1 à 39.pdf"
file_name = PATH_DOCS_PASCALE / "intégrale CR chantier Saint Amand.pdf"

pages = (1, 2)

reader = PdfReader(file_name)
writer = PdfWriter()
page_range = range(pages[0], pages[1] + 1)

for page_num, page in enumerate(reader.pages, 1):
    if page_num in page_range:
        writer.add_page(page)

output_path = f'{file_name}_page_{pages[0]}-{pages[1]}.pdf'
pdf_path = output_path
with open(output_path, 'wb') as out:
    writer.write(out)

# %% [markdown]
# ## Simple OCR - Teseract

# %%
pdf_path = output_path
pdf_path
# Out:
# '/home/secouss/repos/fh-industrie/notebooks/../docs/pascal/intégrale CR chantier Saint Amand.pdf_page_1-7.pdf'

# %%
pages = backend.ocr.ocr_pdf(pdf_path, pages=[1])
# Out:
# PDF converted to 7 images.
# OCR pages: 100%|██████████| 7/7 [00:04<00:00,  1.49it/s]

# %%
print(pages[0])
# Out:
# —
#
# 73 rue Martainville - 76000 ROUEN
#
# Chemin de I'Empire - 59 SAINT AMAND LES EAUX
#
# COMMUNAUTE D'AGGLOMERATION
# DE LA PORTE DU HAINAUT
# Construction d'un centre aquatique
# a St Amand Les Eaux (59
#
# Compte Rendu Réunion MOE
# Du 15 mars 2011
#
# Chantier Tél:
#
# Date OS : 7 mars 2011
# Fax: Délai :
#
# MAITRISE D'OUVRAGE
#
# 20 mois hors intempéries
#
# MAITRE D'OUVRAGE
#
# CAPH
#
# (Communauté d'agglomération
#
# de la Porte de Hainaut)
#
# Rue Michel Rondet
# BP 59
# 59135 WALLERS
#
# Sécrétariat
# M.Alain
# BOCQUET
# (Président)
#
# Mme ROBETTE
# (gestion marchés)
#
# 03 27 09 00 93
# 03 27 09 05 05
#
# 03 27 09 97 58
#
# CAPH Wallers | 99 27 21 09 03
#
# M. DEBAILLEUX | 93 57 g9 91 26 | 06 74 64 02 05 | 03 27 09 91 20
# (rspble projet)
# M. BAUDOUX
#
# (directeur piscine) | 0827 22 49.45 | 06 82 1521 11 | 03 27 22 49.49
#
# 03 27 48 40 90
#
# pdebailleux@aaqglo-
# porteduhainaut.fr
#
# f.baudoux@saint-amand-les-
#
# eaux.fr
#
# drobette@aaqqlo-
# porteduhainaut.fr
# ...

# %% [markdown]
# ## Tabula

# %%
import tabula

# %%
pdf_path
# Out:
# '/home/secouss/repos/fh-industrie/notebooks/../docs/pascal/intégrale CR chantier Saint Amand.pdf_page_1-7.pdf'

# %%
# Read pdf into list of DataFrame
dfs = tabula.read_pdf(pdf_path, pages=[2])
# Out:
# Got stderr: Jun 17, 2025 4:04:19 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font Symbol
# Jun 17, 2025 4:04:19 PM org.apache.pdfbox.pdmodel.font.PDType1Font <init>
# WARNING: Using fallback font LiberationSans for base font ZapfDingbats

# %%
len(dfs)
# Out:
# 1

# %%
dfs[0].head(20)
# Out:
#           LOTS N° :  ENTREPRISES Représentant       Téléphone        Portable  \
# 0             Lot 1         SONDEFOR M. PETIT  05.49.56.59.49  06 12 42 75 03
# 1        FONDATIONS       La Sapinette - BP09             NaN             NaN
# 2               NaN                       NaN             NaN             NaN
# 3         PROFONDES        86800 SAINT JULIEN             NaN             NaN
# 4               NaN                     L'ARS             NaN             NaN
# 5             Lot 2  TOMMASINI M. VANDENBORRE  03.27.53.86.00  06 88 05 98 11
# 6      TERRASSEMENT   Rue de la Fontaine - BP             NaN             NaN
# 7   FONDATIONS - GO                        99             NaN             NaN
# 8               NaN                       NaN             NaN             NaN
# 9               NaN           59620 AULNOYE -             NaN             NaN
# 10              NaN                   AYMERIE             NaN             NaN
# ...

# %%
# Read remote pdf into list of DataFrame
dfs2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/eu-017.pdf", pages=[2], output_format="json")
# Out:
# Got stderr: Jun 17, 2025 3:50:58 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'CenturyGothic'
# Jun 17, 2025 3:50:59 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'LiberationSans' for 'CenturyGothic'

# %%
dfs2[0]
# Out:
# {'extraction_method': 'stream',
#  'top': 70.0,
#  'left': 130.0,
#  'width': 339.0,
#  'height': 490.0,
#  'right': 469.0,
#  'bottom': 560.0,
#  'data': [[{'top': 77.63,
#     'left': 147.48,
#     'width': 303.760009765625,
#     'height': 5.590000152587891,
#     'text': 'Accuracy of the replies obtained from the survey carried out by'}],
#   [{'top': 90.29,
#     'left': 186.06,
#     'width': 223.85000610351562,
#     'height': 5.590000152587891,
#     'text': 'CARSA (2006, Total survey population N=6190)'}],
#   [{'top': 111.47,
#     'left': 285.3,
#     'width': 42.08001708984375,
#     'height': 4.449999809265137,
#     'text': 'Number of'}],
#   [{'top': 116.69,
#     'left': 217.92,
#     'width': 49.27000427246094,
#     'height': 4.449999809265137,
#     'text': 'Valid replies'}],
#   [{'top': 121.85,
#     'left': 155.28,
#     'width': 306.4700012207031,
#     'height': 4.449999809265137,
#     'text': 'Country researchers per d (2) Accuracy Level'}],
# ...

# %%
# convert PDF into CSV file
tabula.convert_into("test.pdf", "output.csv", output_format="csv", pages='all')

# %% [markdown]
# ## Camelot

# %%
pdf_path = PATH_DOCS_PASCALE / "intégrale CR chantier Saint Amand.pdf"

# %%
tables = camelot.read_pdf(pdf_path, pages="116")
tables[0]
# Out:
# <Table shape=(23, 9)>

# %%
tables.export(PATH_TMP / "tmp.csv", f='csv', compress=False) # json, excel, html, markdown, sqlite

# %%
df = pd.read_csv(PATH_TMP / "tmp-page-116-table-1.csv")

# %%
df
# Out:
#                                             LOTS N° :  \
# 0                      Lot 1 \nFONDATIONS \nPROFONDES
# 1              Lot 2 \nTERRASSEMENT \nFONDATIONS - GO
# 2                                      BET STRUCTURES
# 3                        Lot 3 \nTRAITEMENT \nFACADES
# 4             Lot 4 \nCHARPENTE MIXTE \nLAMELLE COLLE
# 5                     Lot 5 \nCOUVERTURE \nETANCHEITE
# 6        Lot 6 \nMEN. \nEXTERIEURES \nINTERIEURES ALU
# 7                      Lot 7 \nPLOMBERIE \nSANITAIRES
# 8   Lot 8 \nTRAITEMENT D'EAU \nANIMATIONS \nAQUATI...
# 9                Lot 9 \nTRAITEMENT D'AIR \nCHAUFFAGE
# 10        Lot 10 \nELECT. COURANTS \nFORTS ET FAIBLES
# 11          Lot 11 \nMENUIS. INT. BOIS \nSIGNALETIQUE
# 12                                Lot 12 \nMETALLERIE
# 13                      Lot 13 \nPLAFONDS \nSUSPENDUS
# 14           Lot 14 \nETANCH. \nREVETEMENT \nCARRELES
# 15     Lot 15 \nPEINTURE \nREV. MURAUX \nSOLS SOUPLES
# ...

# %%
print(df.iloc[1, 1])
# Out:
# -
# Organisation du chantier / OPC :
# (cid:1)
# Suivi des remises des documents par les différents intervenants
# (cid:1)
# Suivi des réceptions par le BET SICRE des réservations des différentes entreprises
# (cid:1)
# Validation des dates de démarrage du chantier : avec en particulier
# (cid:1)
# les dates de mise en place des panneaux de chantier,
# (cid:1)
# des clôtures,
# (cid:1)
# démarrage des déplantations d’arbres, et décapage terres végétales,
# (cid:1)
# réalisation des branchements pour le chantier sur le domaine public
# (cid:1)
# Définition de la date de la réunion avec les concessionnaires
# -
# Questions techniques :
# (cid:1)
# Visite du site pour contrôle des limites de propriété, constat physique des bornes présentes sur le terrain.
# (cid:1)
# Validation de l’implantation des clôtures de chantier.
# (cid:1)
# Identification des différents ouvrages à déposer pour les décapages.
# (cid:1)
# Validation de l’implantation du panneau de chantier.
# (cid:1)
# ...

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 96.78, 'whitespace': 32.47, 'order': 1, 'page': 1}

# %%
tables[0].to_csv('foo.csv') # to_json, to_excel, to_html, to_markdown, to_sqlite
tables[0].df # get a pandas DataFrame!

# %% [markdown]
# ## Extraction images

# %%
from pypdf import PdfReader

# %%
pdf_path
# Out:
# '/home/secouss/repos/fh-industrie/notebooks/../docs/pascal/intégrale CR chantier Saint Amand.pdf_page_1-2.pdf'

# %%
reader = PdfReader(pdf_path)

page = reader.pages[0]
page.images

# %%
len(page.images)
# Out:
# 671

# %%
for count, image_file_object in enumerate(page.images):
    with open("images/" + str(count) + image_file_object.name, "wb") as fp:
        fp.write(image_file_object.data)
